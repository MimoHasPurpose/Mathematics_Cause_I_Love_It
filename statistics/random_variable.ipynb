# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# a= number of vehicles owned
# b= p(a)

# %%
a=[0,1,2,3,4]
b=[0.15,0.235,0.425,0.245,0.080]

# %%
plt.plot(a,b)

# %%
#let x u discrete random varible then its discrete distribution function or cdf.

# %%
def cdf(a):
    sum=0
    for item in a:
        sum=sum+item
    return sum

# %%
a=[0.5,0.5]

# %%
sum=cdf(a)

# %%
sum
# Out:
# 1.0
